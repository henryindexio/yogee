# %%
import pandas as pd
import pickle
f = open('/home/henry/Insight/Yoga_Store_Location_Recommender/Datasets/Yelp_NY_Yoga_Studios_dataset/YogaYelpDfRAW.pckl', 'rb')
YogaYelpDfbackup = pickle.load(f)
f.close()
YogaYelpDfbackup.head(5)
# Out:
#                                          alias  \
# 0                      the-kula-project-groton
# 1                   mystic-yoga-shala-mystic-2
# 2                            up-fitness-mystic
# 3  blissworks-yoga-and-healing-arts-new-london
# 4                    high-street-yoga-westerly
#
#                                           categories  \
# 0  [{'alias': 'yoga', 'title': 'Yoga'}, {'alias':...
# 1               [{'alias': 'yoga', 'title': 'Yoga'}]
# 2  [{'alias': 'barreclasses', 'title': 'Barre Cla...
# 3  [{'alias': 'yoga', 'title': 'Yoga'}, {'alias':...
# 4               [{'alias': 'yoga', 'title': 'Yoga'}]
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 41.3507726899586, 'longitude': -7...  (860) 415-3757
# 1  {'latitude': 41.3442883, 'longitude': -71.9512...  (860) 536-0237
# 2    {'latitude': 41.372018, 'longitude': -71.95588}  (860) 451-4080
# 3  {'latitude': 41.3546676, 'longitude': -72.0972...  (860) 448-9642
# ...

# %%
LandAreaFileLoc = "/home/henry/Insight/Yoga_Store_Location_Recommender/Datasets/Mock_Demographics/Mock_Demographics.csv"
LandAreaDf = pd.read_csv(LandAreaFileLoc)
LandAreaDf.head(5)
# Out:
#    Zip Code  Population  Total_female_population Actual_Mean_Income  \
# 0    6390.0       236.0                      132              62117
# 1   10001.0     21102.0                     3512              75892
# 2   10002.0     81410.0                    11216             148762
# 3   10003.0     56024.0                    40462              67277
# 4   10004.0      3089.0                    29342             145683
#
#     Land_area  Housing Unit   Latitude  Longitude
# 0  10555961.0         660.0  41.273576 -71.968993
# 1   1609401.0       12476.0  40.750672 -73.997281
# 2   2277670.0       34541.0  40.715762 -73.986258
# 3   1493004.0       31078.0  40.731829 -73.989181
# 4   1449744.0        2197.0  40.688630 -74.018244
